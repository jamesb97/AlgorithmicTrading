# %%
# Installing the missing packages in the notebook environment
# !pip install yfinance statsmodels matplotlib pandas
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from datetime import datetime, timedelta

# %%
# Load the dataset
data = yf.download('GOOGLE', start='2010-01-01', end=datetime.now().strftime('%Y-%m-%d'))
data = data['Close']
# Out:
# /var/folders/lh/22w5zzfn4fs82mm7hp75c_0r0000gn/T/ipykernel_12304/1426421560.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download('GOOGLE', start='2010-01-01', end=datetime.now().strftime('%Y-%m-%d'))
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: GOOGLE"}}}
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GOOGLE']: YFTzMissingError('possibly delisted; no timezone found')

# %%
# Visualize the data
data.plot(title='GOOGLE Closing Prices', figsize=(12, 6))
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.show()

# %%
# Store the data
series = data
GOOGL = pd.read_csv('GOOGL.csv', header=0, index_col=0, parse_dates=True)
#series = GOOGL['Close']
# Show the data
print(series.head())
# Out:
# Empty DataFrame
# Columns: [GOOGLE]
# Index: []

# %%
# Clean the price columns by removing '$' and converting to float
GOOGL['Close/Last'] = GOOGL['Close/Last'].str.replace('$', '').astype(float)

# Calculate the average closing price
average_price = GOOGL['Close/Last'].mean()
print(f"Average Closing Price: ${average_price:.2f}")
# Out:
# Average Closing Price: $272.92
